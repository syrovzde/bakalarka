# %%
# %load_ext autoreload
# %autoreload 2
import pandas
import matplotlib.pyplot as plt
import sys
sys.path.append('..')
import market_efficiency.pipeline as pipeline

# %% [markdown]
# # Market efficiency of football football market from available data

# %% [markdown]
# Testing of simple strategies(home bet,away bet, draw,favourite,underdog)

# %%
opened,closed = pipeline.simple_tests(market='bts',fair=False)
opened.cumsum().plot()
closed.cumsum().plot()
# Out:
# loaded
# pre-filter
# pre-results
# starting
# ending
# starting to test
# test_done
# test_done
# test_done
# test_done
# test_done
# opened done
# test_done
# test_done
# test_done
# test_done
# test_done

# %%
opened,closed = pipeline.simple_tests(market='1x2',fair=False)
opened.cumsum().plot()
closed.cumsum().plot()
# Out:
# loaded
# pre-filter
# pre-results
# starting
# ending
# starting to test
# test_done
# test_done
# test_done
# test_done
# test_done
# opened done
# test_done
# test_done
# test_done
# test_done
# test_done

# %%
opened,closed = pipeline.simple_tests(market='ou',fair=False)
opened.cumsum().plot()
closed.cumsum().plot()
# Out:
# loaded
# pre-filter
# pre-results
# starting
# ending
# starting to test
# test_done
# test_done
# test_done
# test_done
# test_done
# opened done
# test_done
# test_done
# test_done
# test_done
# test_done

# %%
fig, axs = plt.subplots(    )
df = pipeline.random_tests(market='1x2',margin='power')
df.boxplot()
plt.show()
df = pipeline.random_tests(market='bts',margin='power')
df.boxplot()
plt.show()
df = pipeline.random_tests(market='ou',margin='power')
df.boxplot()
plt.show()
# Out:
# Cannot convert odds to probs: 3.2,3.0,3.75
# Cannot convert odds to probs: 3.1,3.6,2.87
# Cannot convert odds to probs: 4.2,2.75,5.2
# Cannot convert odds to probs: 4.2,3.22,4.15
# Cannot convert odds to probs: 4.34,2.9,4.5
# Cannot convert odds to probs: 4.09,3.4,3.6
# Cannot convert odds to probs: 99.99,99.99,99.99
# Cannot convert odds to probs: 5.8,2.29,10.5
# Cannot convert odds to probs: 4.09,3.6,3.4
# Cannot convert odds to probs: 3.4,2.25,5.0
# Cannot convert odds to probs: 4.05,2.9,4.7
# Cannot convert odds to probs: 4.59,2.45,7.4
# Cannot convert odds to probs: 4.09,3.4,3.6
# False
# Cannot convert odds to probs: 3.1,3.6,2.87
# Cannot convert odds to probs: 4.2,2.75,5.2
# Cannot convert odds to probs: 4.2,3.22,4.15
# Cannot convert odds to probs: 4.34,2.9,4.5
# Cannot convert odds to probs: 4.09,3.4,3.6
# Cannot convert odds to probs: 3.8,3.35,3.95
# Cannot convert odds to probs: 99.99,99.99,99.99
# Cannot convert odds to probs: 5.8,2.29,10.5
# Cannot convert odds to probs: 4.09,3.6,3.4
# Cannot convert odds to probs: 99.99,99.99,99.99
# Cannot convert odds to probs: 4.05,2.9,4.7
# Cannot convert odds to probs: 4.59,2.45,7.4
# Cannot convert odds to probs: 4.09,3.4,3.6
# False
# False
# Cannot convert odds to probs: 1.22,6.4
# False
# False
# False

# %%
opened,closed = pipeline.kl_test(market='1x2')
print(closed,opened)
opened,closed  = pipeline.kl_test(market='bts')
print(closed,opened)
opened,closed = pipeline.kl_test(market='ou')
print(closed,opened)
# Out:
# 0.08992015639203566 0.09423267633729682
# 0.006682602139352345 0.008777802471366503
# 0.22905911499264442 0.23935791904924986
