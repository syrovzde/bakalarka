# %%
# %load_ext autoreload
# %autoreload 2
import pandas
import matplotlib.pyplot as plt
import sys
sys.path.append('..')
import market_efficiency.pipeline as pipeline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Market efficiency of football football market from available data

# %% [markdown]
# Testing of simple strategies(home bet,away bet, draw,favourite,underdog)

# %%
opened,closed = pipeline.simple_tests()
opened.cumsum().plot()
closed.cumsum().plot()
# Out:
# <class 'numpy.float64'>

# %%
print(opened['home'].cumsum())
print(closed['home'].cumsum())
# Out:
# 0            -1.00
# 1            -2.00
# 2            -3.00
# 3            -4.00
# 4            -5.00
#             ...
# 464221   -34662.91
# 464222   -34663.91
# 464223   -34664.91
# 464224   -34665.91
# 464225   -34666.91
# Name: home, Length: 464226, dtype: float64
# 0            -1.00
# 1            -2.00
# 2            -3.00
# 3            -4.00
# 4            -5.00
#             ...
# 464221   -38194.93
# 464222   -38195.93
# 464223   -38196.93
# 464224   -38197.93
# 464225   -38198.93
# Name: home, Length: 464226, dtype: float64
