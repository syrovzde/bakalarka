# %%
# %load_ext autoreload
# %autoreload 2
import main

# %%
csv_files = ['hockey_ah.csv']
csv_schemas = ['hockey']
csv_markets = ['ah']
bookmakers = [ 'bet-at-home', 'bwin', 'Unibet', 'BetVictor', 'Tipsport.cz', 'Betsafe', 'Pinnacle', 'Chance.cz', 'GoldBet' ,'188BET']

# %%
# %matplotlib inline
main.all_csv_test(csv_files=csv_files,csv_schemas=csv_schemas,csv_markets=csv_markets,bookmakers=bookmakers)
# Out:
# C:\Users\zdesi\PycharmProjects\bakalarka\market_efficiency\helper_functions.py:95: RuntimeWarning: invalid value encountered in greater_equal
#   shifted_difference[shifted_difference >= 0.5] = 1
# C:\Users\zdesi\PycharmProjects\bakalarka\market_efficiency\helper_functions.py:96: RuntimeWarning: invalid value encountered in less_equal
#   shifted_difference[shifted_difference <= -0.5] = -1
