# %%
# %load_ext autoreload
# %autoreload 2
import pandas
import matplotlib.pyplot as plt
import sys
sys.path.append('..')
import market_efficiency.pipeline as pipeline
schema = "basketball"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Market efficiency of football football market from available data

# %% [markdown]
# Testing of simple strategies(home bet,away bet, draw,favourite,underdog)

# %%
opened,closed = pipeline.simple_tests(market='1x2',fair=False,schema=schema)
opened.cumsum().plot()
closed.cumsum().plot()

# %%
opened,closed = pipeline.simple_tests(market='ou',fair=False,schema=schema)
opened.cumsum().plot()
closed.cumsum().plot()

# %%
fig, axs = plt.subplots(    )
df = pipeline.random_tests(market='1x2',margin='power',schema=schema)
df.boxplot()
plt.show()
df = pipeline.random_tests(market='ou',margin='power',schema=schema)
df.boxplot()
plt.show()

# %%
opened,closed = pipeline.kl_test(market='1x2',schema=schema)
print(closed,opened)
opened,closed = pipeline.kl_test(market='ou',schema=schema)
print(closed,opened)#%%#%%
# Out:
# 0.32657052953690346 0.3267332697874754
# 0.01965592173880759 0.01634976690469747
